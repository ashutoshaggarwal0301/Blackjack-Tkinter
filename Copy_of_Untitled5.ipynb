# %% [markdown]
# <a href="https://colab.research.google.com/github/ashutoshaggarwal0301/Blackjack-Tkinter/blob/master/Copy_of_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
myData=pd.read_csv('mycar.csv')
myData
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
x=myData.iloc[:,:-1].values
x
# Out:
# array([[ 4],
#        [ 4],
#        [ 7],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10],
#        [10],
#        [10],
#        [11],
#        [11],
#        [12],
#        [12],
#        [12],
#        [12],
#        [13],
#        [13],
#        [13],
#        [13],
#        [14],
#        [14],
#        [14],
#        [14],
#        [15],
#        [15],
#        [15],
#        [16],
#        [16],
#        [17],
#        [17],
#        [17],
#        [18],
#        [18],
#        [18],
#        [18],
#        [19],
#        [19],
#        [19],
#        [20],
#        [20],
#        [20],
#        [20],
#        [20],
#        [22],
#        [23],
#        [24],
#        [24],
#        [24],
#        [24],
#        [25]])

# %%
myData=pd.read_csv('mycar.csv')
myData
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
x=myData.iloc[:,:-1].values
x
# Out:
# array([[ 4],
#        [ 4],
#        [ 7],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10],
#        [10],
#        [10],
#        [11],
#        [11],
#        [12],
#        [12],
#        [12],
#        [12],
#        [13],
#        [13],
#        [13],
#        [13],
#        [14],
#        [14],
#        [14],
#        [14],
#        [15],
#        [15],
#        [15],
#        [16],
#        [16],
#        [17],
#        [17],
#        [17],
#        [18],
#        [18],
#        [18],
#        [18],
#        [19],
#        [19],
#        [19],
#        [20],
#        [20],
#        [20],
#        [20],
#        [20],
#        [22],
#        [23],
#        [24],
#        [24],
#        [24],
#        [24],
#        [25]])

# %%
y=myData.iloc[:,1].values
y
# Out:
# array([  2,  10,   4,  22,  16,  10,  18,  26,  34,  17,  28,  14,  20,
#         24,  28,  26,  34,  34,  46,  26,  36,  60,  80,  20,  26,  54,
#         32,  40,  32,  40,  50,  42,  56,  76,  84,  36,  46,  68,  32,
#         48,  52,  56,  64,  66,  54,  70,  92,  93, 120,  85])

# %%
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
myData.corr()
# Out:
#           speed      dist
# speed  1.000000  0.806895
# dist   0.806895  1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
# array([[15],
#        [18],
#        [18],
#        [20],
#        [16],
#        [13],
#        [10],
#        [12],
#        [17],
#        [12],
#        [12],
#        [10],
#        [19],
#        [17],
#        [14],
#        [19],
#        [13],
#        [18],
#        [24],
#        [20],
#        [19],
#        [ 9],
#        [16],
#        [23],
#        [20],
#        [25],
#        [ 8],
#        [14],
#        [20],
#        [17],
#        [ 4],
#        [12],
#        [15],
#        [11],
#        [24]])

# %%
from sklearn.linear_model import LinearRegression

# %%
myModel=LinearRegression()

# %%
myModel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
myModel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
myModel.coef_
# Out:
# array([4.11965812])

# %%
myModel.intercept_
# Out:
# -23.094017094017104

# %%
y_pred=myModel.predict(x_test)

# %%
y_pred
# Out:
# array([59.2991453 , 67.53846154,  5.74358974, 30.46153846, -6.61538462,
#        30.46153846, 34.58119658, 22.22222222, 18.1025641 , 34.58119658,
#        75.77777778, 75.77777778,  5.74358974, 38.7008547 , 51.05982906])
